# %% [markdown]
# # 3. Field of 8 inclined boreholes with straight trajectories : (b) Convergence of geothermsim with regards to the discretization
# The convergence of the model is evaluated by comparison with a solution obtained with a fine discretization.

# %%
# Import necessary packages
# Import packages for geothermsim
import geothermsim as gs
from jax import numpy as jnp

# Import packages for visualization
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# ### 3(b).1. Simulation parameters

# %%
# Borehole dimensions
D = 2.0             # Borehole buried depth (m)
L = 150.0           # Borehole length (m)
r_b = 0.075         # Borehole radius (m)
# Borehole spacings (m), tilt (deg), and inclinations (deg)
B = L * 0.025
tilt = jnp.radians(20.)
orientation = jnp.radians(jnp.array([180., 135., -135., 90., -90., 45., -45, 0.]))

# Pipe dimensions
r_out = 0.0211      # Pipe outer radius (m)
r_in = 0.0147       # Pipe inner radius (m)
D_s = 0.052         # Shank spacing (m)
epsilon = 2.12e-5   # Pipe roughness (m)

# Pipe positions
# Single U-tube : [[x_in, y_in], [x_out, y_out]]
p_pipes = jnp.array([[-D_s, 0.], [D_s, 0.]])

# Ground properties
alpha = 1.0e-6      # Ground thermal diffusivity (m2/s)
k_s = 2.0           # Ground thermal conductivity (W/m.K)

# Grout properties
k_b = 1.0           # Grout thermal conductivity (W/m.K)

# Pipe properties
k_p = 0.4           # Pipe thermal conductivity (W/m.K)

# Fluid properties
m_flow_borehole = 0.375 # Total fluid mass flow rate per borehole (kg/s)
m_flow_network = m_flow_borehole * len(orientation)
# The fluid is propylene-glycol (20 %) at 20 degC
cp_f = 3976.8       # Fluid specific heat capacity (in J/kg-K)
rho_f = 1014.8      # Fluid density (kg/m3)
mu_f = 2.0301e-3    # Fluid dynamic viscosity (kg/m.s)
k_f = 0.49221       # Fluid thermal conductivity (W/m.K)

# %% [markdown]
# The convergence of the solution is evaluated near steady-state, at $\ln(t/t_s)=5$.

# %%
ts = L**2 / (9 * alpha)    # Bore field characteristic time
lntts = jnp.array([5.])
time = jnp.exp(lntts) * ts

# %% [markdown]
# ## 3(b).2. Reference solution
# The reference solution is evaluated using $S=20$ segments of $N=11$ nodes (220 nodes in total).

# %%
N_ref = 11
S_ref = 20

basis = gs.Basis.Legendre(N_ref)
ground_heat_exchanger = gs.UTubeHeatExchanger(
    p_pipes, r_in, r_out, r_b, k_s, k_b, k_p, mu_f, rho_f, k_f, cp_f, epsilon)
R_d = ground_heat_exchanger.thermal_resistances
boreholes = []
for i, _orientation in enumerate(orientation):
    boreholes.append(
        gs.SingleUTube.from_dimensions(
            R_d, L, D, r_b, i * B, 0., basis, S_ref, tilt=tilt, orientation=_orientation))
borefield_reference = gs.Network(boreholes)

# %% [markdown]
# The `gFunction` object is initialized and the $g$-function is evaluated.

# %%
gfunc_reference = gs.gFunction(borefield_reference, m_flow_network, cp_f, time, alpha, k_s)
gfunc_reference.simulate()
# Out:
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.83 seconds.
# Initialization end. Elapsed time: 2.84 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.87 seconds.

# %% [markdown]
# ## 3(b).3. Convergence of geothermsim
# The solution is evaluated for numbers of segments ranging from $1$ to $5$ and for numbers of nodes per segment ranging from $1$ to $11$.
#
# The `Borefield` objects are first initialized for each discretization.

# %%
N_max = 11
S_max = 5
n = 0

borefields = []
for _S in range(1, S_max + 1):
    for _N in range(1, N_max + 1):
        basis = gs.Basis.Legendre(_N)
        boreholes = []
        for i, _orientation in enumerate(orientation):
            boreholes.append(
                gs.SingleUTube.from_dimensions(
                    R_d, L, D, r_b, i * B, 0., basis, _S, tilt=tilt, orientation=_orientation))
        borefields.append(gs.Network(boreholes))

# %% [markdown]
# The $g$-functions are then evaluated.

# %%
gfunc = [gs.gFunction(borefield, m_flow_network, cp_f, time, alpha, k_s) for borefield in borefields]
# Out:
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.18 seconds.
# Initialization end. Elapsed time: 3.20 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.92 seconds.
# Initialization end. Elapsed time: 2.95 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 4.48 seconds.
# Initialization end. Elapsed time: 4.50 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.11 seconds.
# Initialization end. Elapsed time: 3.13 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.82 seconds.
# Initialization end. Elapsed time: 2.84 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.47 seconds.
# Initialization end. Elapsed time: 3.49 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.67 seconds.
# Initialization end. Elapsed time: 2.69 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.66 seconds.
# Initialization end. Elapsed time: 2.68 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.68 seconds.
# Initialization end. Elapsed time: 2.71 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.76 seconds.
# Initialization end. Elapsed time: 2.78 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.72 seconds.
# Initialization end. Elapsed time: 3.74 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.56 seconds.
# Initialization end. Elapsed time: 2.56 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.60 seconds.
# Initialization end. Elapsed time: 2.60 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.56 seconds.
# Initialization end. Elapsed time: 2.57 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.63 seconds.
# Initialization end. Elapsed time: 2.63 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.48 seconds.
# Initialization end. Elapsed time: 2.48 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.80 seconds.
# Initialization end. Elapsed time: 3.82 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.58 seconds.
# Initialization end. Elapsed time: 2.60 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.62 seconds.
# Initialization end. Elapsed time: 2.64 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.72 seconds.
# Initialization end. Elapsed time: 2.74 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.73 seconds.
# Initialization end. Elapsed time: 2.75 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.81 seconds.
# Initialization end. Elapsed time: 2.83 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.73 seconds.
# Initialization end. Elapsed time: 2.73 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.49 seconds.
# Initialization end. Elapsed time: 2.49 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.54 seconds.
# Initialization end. Elapsed time: 2.54 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.42 seconds.
# Initialization end. Elapsed time: 2.42 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.59 seconds.
# Initialization end. Elapsed time: 2.61 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.72 seconds.
# Initialization end. Elapsed time: 2.73 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.91 seconds.
# Initialization end. Elapsed time: 2.93 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.76 seconds.
# Initialization end. Elapsed time: 2.78 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.83 seconds.
# Initialization end. Elapsed time: 2.85 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.91 seconds.
# Initialization end. Elapsed time: 2.94 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.15 seconds.
# Initialization end. Elapsed time: 3.17 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.12 seconds.
# Initialization end. Elapsed time: 3.12 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.65 seconds.
# Initialization end. Elapsed time: 2.65 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.58 seconds.
# Initialization end. Elapsed time: 2.58 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.73 seconds.
# Initialization end. Elapsed time: 2.73 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.65 seconds.
# Initialization end. Elapsed time: 2.65 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.62 seconds.
# Initialization end. Elapsed time: 2.62 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 5.21 seconds.
# Initialization end. Elapsed time: 5.23 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.98 seconds.
# Initialization end. Elapsed time: 3.00 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.98 seconds.
# Initialization end. Elapsed time: 3.00 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.01 seconds.
# Initialization end. Elapsed time: 3.03 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 3.31 seconds.
# Initialization end. Elapsed time: 3.34 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.68 seconds.
# Initialization end. Elapsed time: 2.68 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.71 seconds.
# Initialization end. Elapsed time: 2.71 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.66 seconds.
# Initialization end. Elapsed time: 2.67 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.69 seconds.
# Initialization end. Elapsed time: 2.69 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.93 seconds.
# Initialization end. Elapsed time: 2.95 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.60 seconds.
# Initialization end. Elapsed time: 2.60 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.83 seconds.
# Initialization end. Elapsed time: 2.85 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.59 seconds.
# Initialization end. Elapsed time: 2.59 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.84 seconds.
# Initialization end. Elapsed time: 2.86 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.76 seconds.
# Initialization end. Elapsed time: 2.78 seconds.
# Initialization start.
# Completed thermal response factors to nodes. Elapsed time: 2.78 seconds.
# Initialization end. Elapsed time: 2.80 seconds.

# %%
for _gfunc in gfunc:
    _gfunc.simulate()
values = jnp.array([_gfunc.g[-1] for _gfunc in gfunc]).reshape(S_max, N_max).T
# Out:
# Simulation start.
# Simulation end. Elapsed time: 3.09 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.09 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.11 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.15 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.01 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.05 seconds.
# Simulation start.
# Simulation end. Elapsed time: 6.41 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.14 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.20 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.17 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.17 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.88 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.80 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.77 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.79 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.79 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.17 seconds.
# Simulation start.
# Simulation end. Elapsed time: 6.75 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.29 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.23 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.22 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.28 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.83 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.77 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.79 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.80 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.19 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.02 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.24 seconds.
# Simulation start.
# Simulation end. Elapsed time: 7.04 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.21 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.30 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.18 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.86 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.84 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.82 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.88 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.91 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.81 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.46 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.26 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.25 seconds.
# Simulation start.
# Simulation end. Elapsed time: 7.54 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.53 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.03 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.80 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.77 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.83 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.25 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.89 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.19 seconds.
# Simulation start.
# Simulation end. Elapsed time: 2.89 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.23 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.31 seconds.
# Simulation start.
# Simulation end. Elapsed time: 3.38 seconds.

# %%
# Format and print dataframe
df = pd.DataFrame(
    values,
    columns=[f'S = {_S}' for _S in jnp.arange(1, S_max + 1)],
    index=jnp.arange(1, N_max + 1))
df.index.name = 'N'
df.style.set_caption(r'$g$-Function at $ln(t/t_s)=5$')
# Out:
# <style type="text/css">
# </style>
# <table id="T_8f152">
#   <caption>$g$-Function at $ln(t/t_s)=5$</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f152_level0_col0" class="col_heading level0 col0" >S = 1</th>
#       <th id="T_8f152_level0_col1" class="col_heading level0 col1" >S = 2</th>
#       <th id="T_8f152_level0_col2" class="col_heading level0 col2" >S = 3</th>
#       <th id="T_8f152_level0_col3" class="col_heading level0 col3" >S = 4</th>
#       <th id="T_8f152_level0_col4" class="col_heading level0 col4" >S = 5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >N</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f152_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8f152_row0_col0" class="data row0 col0" >12.869993</td>
#       <td id="T_8f152_row0_col1" class="data row0 col1" >12.297020</td>
#       <td id="T_8f152_row0_col2" class="data row0 col2" >12.079844</td>
#       <td id="T_8f152_row0_col3" class="data row0 col3" >11.957018</td>
#       <td id="T_8f152_row0_col4" class="data row0 col4" >11.875279</td>
#     </tr>
#     <tr>
#       <th id="T_8f152_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8f152_row1_col0" class="data row1 col0" >12.084939</td>
#       <td id="T_8f152_row1_col1" class="data row1 col1" >11.808675</td>
#       <td id="T_8f152_row1_col2" class="data row1 col2" >11.708837</td>
#       <td id="T_8f152_row1_col3" class="data row1 col3" >11.656541</td>
#       <td id="T_8f152_row1_col4" class="data row1 col4" >11.623466</td>
#     </tr>
#     <tr>
#       <th id="T_8f152_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_8f152_row2_col0" class="data row2 col0" >11.811347</td>
#       <td id="T_8f152_row2_col1" class="data row2 col1" >11.657569</td>
#       <td id="T_8f152_row2_col2" class="data row2 col2" >11.603534</td>
#       <td id="T_8f152_row2_col3" class="data row2 col3" >11.574363</td>
#       <td id="T_8f152_row2_col4" class="data row2 col4" >11.557339</td>
#     </tr>
#     <tr>
#       <th id="T_8f152_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_8f152_row3_col0" class="data row3 col0" >11.688241</td>
#       <td id="T_8f152_row3_col1" class="data row3 col1" >11.591563</td>
#       <td id="T_8f152_row3_col2" class="data row3 col2" >11.557914</td>
#       <td id="T_8f152_row3_col3" class="data row3 col3" >11.542285</td>
#       <td id="T_8f152_row3_col4" class="data row3 col4" >11.534646</td>
#     </tr>
#     <tr>
#       <th id="T_8f152_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_8f152_row4_col0" class="data row4 col0" >11.622027</td>
#       <td id="T_8f152_row4_col1" class="data row4 col1" >11.558993</td>
#       <td id="T_8f152_row4_col2" class="data row4 col2" >11.538395</td>
#       <td id="T_8f152_row4_col3" class="data row4 col3" >11.530089</td>
#       <td id="T_8f152_row4_col4" class="data row4 col4" >11.526008</td>
#     </tr>
#     <tr>
#       <th id="T_8f152_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_8f152_row5_col0" class="data row5 col0" >11.584891</td>
#       <td id="T_8f152_row5_col1" class="data row5 col1" >11.541690</td>
#       <td id="T_8f152_row5_col2" class="data row5 col2" >11.528893</td>
#       <td id="T_8f152_row5_col3" class="data row5 col3" >11.523868</td>
#       <td id="T_8f152_row5_col4" class="data row5 col4" >11.521091</td>
#     </tr>
#     <tr>
#       <th id="T_8f152_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_8f152_row6_col0" class="data row6 col0" >11.562251</td>
#       <td id="T_8f152_row6_col1" class="data row6 col1" >11.532382</td>
#       <td id="T_8f152_row6_col2" class="data row6 col2" >11.523662</td>
#       <td id="T_8f152_row6_col3" class="data row6 col3" >11.520156</td>
#       <td id="T_8f152_row6_col4" class="data row6 col4" >11.517907</td>
#     </tr>
#     <tr>
#       <th id="T_8f152_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_8f152_row7_col0" class="data row7 col0" >11.548535</td>
#       <td id="T_8f152_row7_col1" class="data row7 col1" >11.526527</td>
#       <td id="T_8f152_row7_col2" class="data row7 col2" >11.520244</td>
#       <td id="T_8f152_row7_col3" class="data row7 col3" >11.517516</td>
#       <td id="T_8f152_row7_col4" class="data row7 col4" >11.515522</td>
#     </tr>
#     <tr>
#       <th id="T_8f152_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_8f152_row8_col0" class="data row8 col0" >11.539741</td>
#       <td id="T_8f152_row8_col1" class="data row8 col1" >11.522575</td>
#       <td id="T_8f152_row8_col2" class="data row8 col2" >11.517815</td>
#       <td id="T_8f152_row8_col3" class="data row8 col3" >11.515476</td>
#       <td id="T_8f152_row8_col4" class="data row8 col4" >11.513643</td>
#     </tr>
#     <tr>
#       <th id="T_8f152_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_8f152_row9_col0" class="data row9 col0" >11.533767</td>
#       <td id="T_8f152_row9_col1" class="data row9 col1" >11.519593</td>
#       <td id="T_8f152_row9_col2" class="data row9 col2" >11.515877</td>
#       <td id="T_8f152_row9_col3" class="data row9 col3" >11.513751</td>
#       <td id="T_8f152_row9_col4" class="data row9 col4" >11.512058</td>
#     </tr>
#     <tr>
#       <th id="T_8f152_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_8f152_row10_col0" class="data row10 col0" >11.529517</td>
#       <td id="T_8f152_row10_col1" class="data row10 col1" >11.517533</td>
#       <td id="T_8f152_row10_col2" class="data row10 col2" >11.514489</td>
#       <td id="T_8f152_row10_col3" class="data row10 col3" >11.512467</td>
#       <td id="T_8f152_row10_col4" class="data row10 col4" >11.510980</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The relative error is calculated from the difference between the solution and the reference:
# $$
# \varepsilon_{rel} = \frac{g - g_{ref}}{g_{ref}}
# $$

# %%
error = (jnp.array([_gfunc.g[-1] for _gfunc in gfunc]).reshape(S_max, N_max).T - gfunc_reference.g[-1]) / gfunc_reference.g[-1]

# %%
# Format and print dataframe
df = pd.DataFrame(
    error,
    columns=[f'S = {_S}' for _S in jnp.arange(1, S_max + 1)],
    index=jnp.arange(1, N_max + 1))
df.index.name = 'N'
df.style.set_caption(r'Relative error on the $g$-function at $ln(t/t_s)=5$')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c142c">
#   <caption>Relative error on the $g$-function at $ln(t/t_s)=5$</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c142c_level0_col0" class="col_heading level0 col0" >S = 1</th>
#       <th id="T_c142c_level0_col1" class="col_heading level0 col1" >S = 2</th>
#       <th id="T_c142c_level0_col2" class="col_heading level0 col2" >S = 3</th>
#       <th id="T_c142c_level0_col3" class="col_heading level0 col3" >S = 4</th>
#       <th id="T_c142c_level0_col4" class="col_heading level0 col4" >S = 5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >N</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c142c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c142c_row0_col0" class="data row0 col0" >0.118447</td>
#       <td id="T_c142c_row0_col1" class="data row0 col1" >0.068653</td>
#       <td id="T_c142c_row0_col2" class="data row0 col2" >0.049780</td>
#       <td id="T_c142c_row0_col3" class="data row0 col3" >0.039106</td>
#       <td id="T_c142c_row0_col4" class="data row0 col4" >0.032003</td>
#     </tr>
#     <tr>
#       <th id="T_c142c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c142c_row1_col0" class="data row1 col0" >0.050223</td>
#       <td id="T_c142c_row1_col1" class="data row1 col1" >0.026214</td>
#       <td id="T_c142c_row1_col2" class="data row1 col2" >0.017538</td>
#       <td id="T_c142c_row1_col3" class="data row1 col3" >0.012993</td>
#       <td id="T_c142c_row1_col4" class="data row1 col4" >0.010119</td>
#     </tr>
#     <tr>
#       <th id="T_c142c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c142c_row2_col0" class="data row2 col0" >0.026447</td>
#       <td id="T_c142c_row2_col1" class="data row2 col1" >0.013083</td>
#       <td id="T_c142c_row2_col2" class="data row2 col2" >0.008387</td>
#       <td id="T_c142c_row2_col3" class="data row2 col3" >0.005852</td>
#       <td id="T_c142c_row2_col4" class="data row2 col4" >0.004372</td>
#     </tr>
#     <tr>
#       <th id="T_c142c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_c142c_row3_col0" class="data row3 col0" >0.015748</td>
#       <td id="T_c142c_row3_col1" class="data row3 col1" >0.007347</td>
#       <td id="T_c142c_row3_col2" class="data row3 col2" >0.004422</td>
#       <td id="T_c142c_row3_col3" class="data row3 col3" >0.003064</td>
#       <td id="T_c142c_row3_col4" class="data row3 col4" >0.002400</td>
#     </tr>
#     <tr>
#       <th id="T_c142c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_c142c_row4_col0" class="data row4 col0" >0.009994</td>
#       <td id="T_c142c_row4_col1" class="data row4 col1" >0.004516</td>
#       <td id="T_c142c_row4_col2" class="data row4 col2" >0.002726</td>
#       <td id="T_c142c_row4_col3" class="data row4 col3" >0.002004</td>
#       <td id="T_c142c_row4_col4" class="data row4 col4" >0.001650</td>
#     </tr>
#     <tr>
#       <th id="T_c142c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_c142c_row5_col0" class="data row5 col0" >0.006767</td>
#       <td id="T_c142c_row5_col1" class="data row5 col1" >0.003012</td>
#       <td id="T_c142c_row5_col2" class="data row5 col2" >0.001900</td>
#       <td id="T_c142c_row5_col3" class="data row5 col3" >0.001464</td>
#       <td id="T_c142c_row5_col4" class="data row5 col4" >0.001222</td>
#     </tr>
#     <tr>
#       <th id="T_c142c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_c142c_row6_col0" class="data row6 col0" >0.004799</td>
#       <td id="T_c142c_row6_col1" class="data row6 col1" >0.002204</td>
#       <td id="T_c142c_row6_col2" class="data row6 col2" >0.001446</td>
#       <td id="T_c142c_row6_col3" class="data row6 col3" >0.001141</td>
#       <td id="T_c142c_row6_col4" class="data row6 col4" >0.000946</td>
#     </tr>
#     <tr>
#       <th id="T_c142c_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_c142c_row7_col0" class="data row7 col0" >0.003607</td>
#       <td id="T_c142c_row7_col1" class="data row7 col1" >0.001695</td>
#       <td id="T_c142c_row7_col2" class="data row7 col2" >0.001149</td>
#       <td id="T_c142c_row7_col3" class="data row7 col3" >0.000912</td>
#       <td id="T_c142c_row7_col4" class="data row7 col4" >0.000738</td>
#     </tr>
#     <tr>
#       <th id="T_c142c_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_c142c_row8_col0" class="data row8 col0" >0.002843</td>
#       <td id="T_c142c_row8_col1" class="data row8 col1" >0.001351</td>
#       <td id="T_c142c_row8_col2" class="data row8 col2" >0.000938</td>
#       <td id="T_c142c_row8_col3" class="data row8 col3" >0.000734</td>
#       <td id="T_c142c_row8_col4" class="data row8 col4" >0.000575</td>
#     </tr>
#     <tr>
#       <th id="T_c142c_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_c142c_row9_col0" class="data row9 col0" >0.002324</td>
#       <td id="T_c142c_row9_col1" class="data row9 col1" >0.001092</td>
#       <td id="T_c142c_row9_col2" class="data row9 col2" >0.000769</td>
#       <td id="T_c142c_row9_col3" class="data row9 col3" >0.000584</td>
#       <td id="T_c142c_row9_col4" class="data row9 col4" >0.000437</td>
#     </tr>
#     <tr>
#       <th id="T_c142c_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_c142c_row10_col0" class="data row10 col0" >0.001955</td>
#       <td id="T_c142c_row10_col1" class="data row10 col1" >0.000913</td>
#       <td id="T_c142c_row10_col2" class="data row10 col2" >0.000649</td>
#       <td id="T_c142c_row10_col3" class="data row10 col3" >0.000473</td>
#       <td id="T_c142c_row10_col4" class="data row10 col4" >0.000344</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plot error as function of N and S
fig, axs = plt.subplots(ncols=2, sharey=True, layout='constrained')

N = jnp.arange(1, N_max + 1)
S = jnp.arange(1, S_max + 1)

axs[0].set_xscale('function', functions=(lambda x: jnp.log(x), lambda x: jnp.exp(x)))
axs[0] = gs.plot._format_axis(axs[0], axis_labels=[r'$N$', r'$log_{10}(\varepsilon_{rel})$'])
axs[0].plot(N, jnp.log10(error), '-o');
axs[0].plot(N, jnp.log10(0.1 / N**2), 'k--');
axs[0].legend([f'$S={_S}$' for _S in S] + [r'$1 / N^2$'], frameon=False)

axs[1].set_xscale('function', functions=(lambda x: jnp.log(x), lambda x: jnp.exp(x)))
axs[1] = gs.plot._format_axis(axs[1])
axs[1].set_xlabel(r'S')
axs[1].plot(S, jnp.log10(error.T), '-o');
axs[1].plot(S, jnp.log10(0.01 / S), 'k--');
axs[1].set_xlim(None, 20)
axs[1].legend([f'$N={_N}$' for _N in N] + [r'$1 / S$'], frameon=False)

fig.set_size_inches(140. / 25.4, 90. / 25.4)
fig.savefig('convergence-Eskilson-optimal.eps')
